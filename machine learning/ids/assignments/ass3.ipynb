# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
import numpy as np

# Mean
data = [10,25,5,30,45,80,90,125]
x = np.mean(data)
print(x)

# Median
y = np.median(data)
print(y)
from scipy  import stats

speed = [10,25,5,30,45,80,90,125]

x = stats.mode(speed)
print(x)
from scipy.stats import skew 
import matplotlib.pyplot as plt
import seaborn

dataset = [10,25,5,30,45,80,90,125]
print(skew(dataset))
import seaborn as sns 
sns.kdeplot(dataset)
plt.show()
from scipy.stats import skew 
import matplotlib.pyplot as plt
import seaborn

dataset = [10,25,5,30,45,80,90,125]
print(skew(dataset))
import seaborn as sns 
sns.kdeplot(dataset)
plt.show()

import numpy as np

speed = [10,25,5,30,45,80,90,125]
x = np.std(speed)
print(x)

import numpy as np

speed = [10,25,5,30,45,80,90,125]
x = np.std(speed)
print(x)

from scipy.stats import kurtosis 
import matplotlib.pyplot as plt
dataset = [10,25,5,30,45,80,90,125]
print(kurtosis(dataset))
import seaborn as sns

sns.kdeplot(dataset)
plt.show()
print("Aryan Sinha")
# Out:
# 51.25
# 37.5
# ModeResult(mode=5, count=1)
# 0.5594741272186756
# 0.5594741272186756
# 39.98046397929869
# 39.98046397929869
# -1.0101564314032387
# Aryan Sinha

# %%
import matplotlib.pyplot as plt

# Data
data = {'a': [200, 50, 300],'b': [90, 20, 200]}

# Creating box plot
plt.boxplot(data.values(), labels=data.keys())
plt.xlabel('Group')
plt.ylabel('Values')
plt.title('Box Plot of Data')
plt.grid(True)
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,100,86,103,87,94,78,77,85,86]

plt.scatter(x,y,c='blue')
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
import matplotlib.pyplot as plt 

x = [10,20,30,40,50]
y = [30,30,30,30,30]


plt.plot(x,y, label = "line 1")
plt.plot(y,x, label = "line 2")

plt.legend()
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
#Histograms
# The hist2d() function in pyplot module of the matplotlib library used to make a 2d Histogram
import matplotlib.pyplot as plt
import numpy as np

data=np.random.randn(1000)
plt.hist(data,bins=10,color="blue",edgecolor="black")
plt.xlabel('Density')
plt.ylabel('Values')
plt.title('Histogram')
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
import matplotlib.pyplot as plt
import numpy as np
cars=["Audi","Bmw",'Jaguar',"Mercedes"]
data=[34,24,25,17]
plt.bar(height=data,x=cars)
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
#Wireframe Plot n Surface PLots
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
fig=plt.figure()
ax=fig.add_subplot(projection='3d')

x,y,z=axes3d.get_test_data(0.05)

ax.plot_surface(x,y,z,rstride=10,cstride=10) #or plot_wireframe
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
#Wireframe Plot n Surface PLots
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
fig=plt.figure()
ax=fig.add_subplot(projection='3d')

x,y,z=axes3d.get_test_data(0.05)

ax.plot_wireframe(x,y,z,rstride=10,cstride=10) #or plot_wireframe
plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()

# Contour Plot
ax_contour = fig.add_subplot(133, projection="3d")
ax_contour.contour(x,y,z, 50)
ax_contour.set_title('Contour Plot')


plt.show()
print("Aryan Sinha")
# Out:
# Aryan Sinha
