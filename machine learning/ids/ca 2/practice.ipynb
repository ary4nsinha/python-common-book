# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy import stats

# %%
from scipy.stats import skew
dataset = [88, 85, 82, 97, 67, 77, 74, 86,81, 95, 77, 88, 85, 76, 81]
print(skew(dataset))
# Out:
# 0.029331688766181797

# %%
from scipy.stats import kurtosis
print(kurtosis(dataset))
import seaborn as sns
sns.kdeplot(dataset)
# Out:
# -0.29271198374234686
# <Axes: ylabel='Density'>

# %%
import numpy as np
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 3, 9, 1])
correlation_coefficient = np.corrcoef(x, y)
print(correlation_coefficient)
# Out:
# [[ 1.  -0.3]
#  [-0.3  1. ]]

# %%
import pandas as pd
data = pd.DataFrame({'X': [1, 2, 3, 4, 5], 'Y': [5, 7, 3, 9, 1]})
correlation_coefficient = data['X'].corr(data['Y'])
print(correlation_coefficient)
# Out:
# -0.3

# %%
import numpy as np 
import matplotlib.pyplot as plt 

dataSet1= [23,45,32,22,1,3,5,7,55,74,33,25,22,54,43,56,87,66,33,22]
dataSet2= [13,25,22,82,6,78,8,43,42,75,87,77,74,41,12,1,11,26,78,3]

plt.title('Scatter plot example')
plt.xlabel('Number')
plt.ylabel('noo')
plt.scatter(dataSet1,dataSet2)

# %%
# contour plots 
import matplotlib.pyplot as plt 
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
X,Y = np.meshgrid(x,y)
Z = np.sin(X) + np.cos(Y)


fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

ax.contour3D(X,Y,Z,50,cmap='viridis')


ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('z-axis')

ax.set_title('Basic 3D Comtour Plot')

plt.show()

# %%
# plotting surface triangulation 
import matplotlib.pyplot as plt 
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d

z= np.linspace(0,50000,100)

x = np.sin(z)
y = np.cos(z)


fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x,y,z,linewidth = 0.2)
plt.show()

# %%
'''
ANOVA stands for analysis of variance 
is an analysis tool used in statistics that splits an offest aggregate variabiility found inside the dataset 
2. the anova test determines the influence that independent variables have on dependent variables in a regression study 
3. the anova test allows the comparison of more than two groups at the same time to determine whether a relationship exists between them.
the result of the anova formula, the fstatistics also called (F.ratio) allows for the analysis of multiple groups of data to determine the variability between samples and witin the samples 
anova is a statistical method that separates observed variance data into different components to use for additional tests 
1-04-2024
one-way anova is used for three or more groups of data to gain information about the relationship between the dependent and the independent variables
if no two varieance exists between the groups, the anova fratio should = close to one 
if the fstatistic exceeds a critical value, it indicates significant difference between 



'''

# %%
from scipy.stats import skew

# Given data
data = [2, 4, 6, 6]

# Calculate skewness
skewness = skew(data)
print("Skewness of the data:", skewness)
# Out:
# Skewness of the data: -0.49338220021815865

# %%
from scipy.stats import skew

data = [25, 28, 26, 30, 40, 50, 40]
skewness = skew(data)
print("Skewness of the data:", skewness)
# Out:
# Skewness of the data: 0.6121401272403957
